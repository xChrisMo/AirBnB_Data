# %% [markdown]
# # PROJECT: REVIEWING BOSTON'S AIRBNB  DATA
#
# Name: Ayo Mosaku

# %% [markdown]
# ### Table of Contents
# * Introduction
# * Data Accessment
# * Data Wrangling
# * Exploratory Data Analysis
# * Data Preprocessing
# * Model Building
# * Project Objective

# %% [markdown]
# # SECTION I: INTRODUCTION

# %% [markdown]
# #### Dataset: Boston Airbnb Data as referrenced here: https://www.kaggle.com/datasets/airbnb/boston.
#
# Description: The AirBnb Activity Dataset to be used here is comprised of two related datasets really;

# %% [markdown]
# ### 1. 'Reviews' Dataset: This includes unique id for each reviewer and detailed comments.
# Column Description:
#
# * __listing_id__: For every listing, this explicitly shows the ID generated for it, it is its primary key.
# * __id__: This column provides a unique identifier for each review
# * __date__: Shows date of review
# * __reviewer_id__: Gives the unique ID for each reviewer.
# * __reviewer_name__: Name for who put the review in
# * __comments__: words describing each reviewed property

# %% [markdown]
# ### 2. 'Listings' Dataset: This includes the full descriptions and average review score amongst many other things
#
# Column Description:
#
# DUE TO COMPLEXITY, NOT ALL OF THIS DATASET'S COLUMNS CAN and WOULD BE EXPLAINED REALLY
#
# * __listing_id__: For every listing, this explicitly shows the ID generated for it, it is its primary key.
# * __listing_url__: link for accessing the property online
# * __description__: describing the listing in question
# * __neighbourhood__: location of airbnb listing
# * __property_type__: explains a bit more what sort of property the listing is
# * __host_verification__: pass check as done in accordance to AirBnB's policies
# * __price__: base price for airbnb listing.
# * __cancellation_policy__: explains how to cancel the listing's booking

# %% [markdown]
# ### Research Questions:
#
# 1. What is the general outlook of the reviews comments ?
# 2. As a prospective Airbnb host, what sort of apartment do I need to have to increase my chances of making profit off rentals
# 3. What factors affect price the most really ?

# %% [markdown]
# #### Research Areas:
#
# 1. __Target Variable(Price)__: We aim to explore how the price of Airbnb listings fare in respect to other factors
#
# 2. __Univariate Analysis__: Asides price, we would aim to explore the columns in context in-depth
#
# 3. __Bivariate Analysis__: Here, although other factors are considered, we have a bias towards determine the factors that alter our 'price' the most
#
# 4. __Multivariate Analysis__: Here, we would take a deeper dive into how more than 2 columns affect one another. Remember, there is still a bias towards exploring our target variable

# %% [markdown]
# ### Limitations
#
# 1. Multiple occurence of listing_id's make the merge process a bit messy
# 2. There is quite a number of columns with very little to no context
# 3. The data is very inconsistent and has some of its values invalid

# %%
#importing all required libraries

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import re
import nltk

import warnings
warnings.filterwarnings('ignore')

# %%
#importing models, modules and frameworks needed

import sklearn
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestRegressor

from xgboost import XGBRegressor

from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
reviews = pd.read_csv('reviews.csv')

# %%
listings = pd.read_csv('listings.csv')

# %% [markdown]
# # SECTION II: DATA ACCESSING
#
# Here, we initially try read our data, alongside reviewing its different qualities to gain context

# %%
reviews.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0     1178162  4724140  2013-05-21      4298113       Olivier
# 1     1178162  4869189  2013-05-29      6452964     Charlotte
# 2     1178162  5003196  2013-06-06      6449554     Sebastian
# 3     1178162  5150351  2013-06-15      2215611        Marine
# 4     1178162  5171140  2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68275 entries, 0 to 68274
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   listing_id     68275 non-null  int64
#  1   id             68275 non-null  int64
#  2   date           68275 non-null  object
#  3   reviewer_id    68275 non-null  int64
#  4   reviewer_name  68275 non-null  object
#  5   comments       68222 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 3.1+ MB

# %%
listings.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...                 NaN
# 1  The room is in Roslindale, a diverse and prima...  ...                 9.0
# 2  The LOCATION: Roslindale is a safe and diverse...  ...                10.0
# 3  Roslindale is a lovely little neighborhood loc...  ...                10.0
# 4  I love the proximity to downtown, the neighbor...  ...                10.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                t
# 2                f     NaN                NaN                f
# 3                f     NaN                NaN                f
# 4                f     NaN                NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             t
# 3            moderate                             f
# 4            flexible                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#    reviews_per_month
# 0                NaN
# 1               1.30
# 2               0.47
# 3               1.00
# 4               2.25
#
# [5 rows x 95 columns]

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585 entries, 0 to 3584
# Data columns (total 95 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3585 non-null   int64
#  1   listing_url                       3585 non-null   object
#  2   scrape_id                         3585 non-null   int64
#  3   last_scraped                      3585 non-null   object
#  4   name                              3585 non-null   object
#  5   summary                           3442 non-null   object
#  6   space                             2528 non-null   object
#  7   description                       3585 non-null   object
#  8   experiences_offered               3585 non-null   object
#  9   neighborhood_overview             2170 non-null   object
#  10  notes                             1610 non-null   object
#  11  transit                           2295 non-null   object
#  12  access                            2096 non-null   object
#  13  interaction                       2031 non-null   object
#  14  house_rules                       2393 non-null   object
#  15  thumbnail_url                     2986 non-null   object
#  16  medium_url                        2986 non-null   object
#  17  picture_url                       3585 non-null   object
#  18  xl_picture_url                    2986 non-null   object
#  19  host_id                           3585 non-null   int64
#  20  host_url                          3585 non-null   object
#  21  host_name                         3585 non-null   object
#  22  host_since                        3585 non-null   object
#  23  host_location                     3574 non-null   object
#  24  host_about                        2276 non-null   object
#  25  host_response_time                3114 non-null   object
#  26  host_response_rate                3114 non-null   object
#  27  host_acceptance_rate              3114 non-null   object
#  28  host_is_superhost                 3585 non-null   object
#  29  host_thumbnail_url                3585 non-null   object
#  30  host_picture_url                  3585 non-null   object
#  31  host_neighbourhood                3246 non-null   object
#  32  host_listings_count               3585 non-null   int64
#  33  host_total_listings_count         3585 non-null   int64
#  34  host_verifications                3585 non-null   object
#  35  host_has_profile_pic              3585 non-null   object
#  36  host_identity_verified            3585 non-null   object
#  37  street                            3585 non-null   object
#  38  neighbourhood                     3042 non-null   object
#  39  neighbourhood_cleansed            3585 non-null   object
#  40  neighbourhood_group_cleansed      0 non-null      float64
#  41  city                              3583 non-null   object
#  42  state                             3585 non-null   object
#  43  zipcode                           3547 non-null   object
#  44  market                            3571 non-null   object
#  45  smart_location                    3585 non-null   object
#  46  country_code                      3585 non-null   object
#  47  country                           3585 non-null   object
#  48  latitude                          3585 non-null   float64
#  49  longitude                         3585 non-null   float64
#  50  is_location_exact                 3585 non-null   object
#  51  property_type                     3582 non-null   object
#  52  room_type                         3585 non-null   object
#  53  accommodates                      3585 non-null   int64
#  54  bathrooms                         3571 non-null   float64
#  55  bedrooms                          3575 non-null   float64
#  56  beds                              3576 non-null   float64
#  57  bed_type                          3585 non-null   object
#  58  amenities                         3585 non-null   object
#  59  square_feet                       56 non-null     float64
#  60  price                             3585 non-null   object
#  61  weekly_price                      892 non-null    object
#  62  monthly_price                     888 non-null    object
#  63  security_deposit                  1342 non-null   object
#  64  cleaning_fee                      2478 non-null   object
#  65  guests_included                   3585 non-null   int64
#  66  extra_people                      3585 non-null   object
#  67  minimum_nights                    3585 non-null   int64
#  68  maximum_nights                    3585 non-null   int64
#  69  calendar_updated                  3585 non-null   object
#  70  has_availability                  0 non-null      float64
#  71  availability_30                   3585 non-null   int64
#  72  availability_60                   3585 non-null   int64
#  73  availability_90                   3585 non-null   int64
#  74  availability_365                  3585 non-null   int64
#  75  calendar_last_scraped             3585 non-null   object
#  76  number_of_reviews                 3585 non-null   int64
#  77  first_review                      2829 non-null   object
#  78  last_review                       2829 non-null   object
#  79  review_scores_rating              2772 non-null   float64
#  80  review_scores_accuracy            2762 non-null   float64
#  81  review_scores_cleanliness         2767 non-null   float64
#  82  review_scores_checkin             2765 non-null   float64
#  83  review_scores_communication       2767 non-null   float64
#  84  review_scores_location            2763 non-null   float64
#  85  review_scores_value               2764 non-null   float64
#  86  requires_license                  3585 non-null   object
#  87  license                           0 non-null      float64
#  88  jurisdiction_names                0 non-null      float64
#  89  instant_bookable                  3585 non-null   object
#  90  cancellation_policy               3585 non-null   object
#  91  require_guest_profile_picture     3585 non-null   object
#  92  require_guest_phone_verification  3585 non-null   object
#  93  calculated_host_listings_count    3585 non-null   int64
#  94  reviews_per_month                 2829 non-null   float64
# dtypes: float64(18), int64(15), object(62)
# memory usage: 2.6+ MB

# %% [markdown]
# ### 1. Missing Values

# %%
reviews.isna().sum()
# Out:
# listing_id        0
# id                0
# date              0
# reviewer_id       0
# reviewer_name     0
# comments         53
# dtype: int64

# %%
listings.isna().sum().sort_values(ascending=False)
# Out:
# has_availability                3585
# license                         3585
# neighbourhood_group_cleansed    3585
# jurisdiction_names              3585
# square_feet                     3529
#                                 ...
# is_location_exact                  0
# room_type                          0
# accommodates                       0
# bed_type                           0
# country                            0
# Length: 95, dtype: int64

# %% [markdown]
# ### 2. Duplicates

# %%
reviews.duplicated().sum()
# Out:
# 0

# %%
listings.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 3. Further Checks.
#
# __#NOTE:__
# We are careful not to clean this data, nor validate some of its values too early as it might affect our Models to be built

# %% [markdown]
# # SECTION III: DATA WRANGLING

# %% [markdown]
# #### To really wrangle, our main objective is to 'filter' these datasets, merge them and perform some intuitive feature engineering

# %% [markdown]
# Honestly, our unison goal here is on two exact basis:
#
# 1. We use Sentiment Analysis using VADER to categorise the 'comments' column in the reviews dataframe
# 2. We merge all columns innerly; that is, only account for what they all share
#
# All of these are out steps to take BEFORE cleaning begins

# %% [markdown]
# Sentiment Analysis on our Reviews using VADER

# %%
analyze = SentimentIntensityAnalyzer()

# %%
statement1 = 'Ayo is a good boy'      #Testing Vader's polarities
statement2 = 'Ayo is a bad boy'
statement3 = 'Ayo is a very good boy'

# %%
print(analyze.polarity_scores(statement1))
print(analyze.polarity_scores(statement2))
print(analyze.polarity_scores(statement3))
# Out:
# {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# {'neg': 0.538, 'neu': 0.462, 'pos': 0.0, 'compound': -0.5423}
# {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.4927}

# %%
#From above we can confirm our VADER is decent enough for our comments prediction

# %%
reviews['comments'] = reviews['comments'].fillna('')

# %%
reviews.isna().sum()
# Out:
# listing_id       0
# id               0
# date             0
# reviewer_id      0
# reviewer_name    0
# comments         0
# dtype: int64

# %%
def sentiment_analyzer(comment):
    '''Defining a function to help check the polarity scores of review comments'''
    score = analyze.polarity_scores(comment)
    if score['compound'] >= 0.1:
        return 'Positive'
    elif score['compound'] < -0.1:
        return 'Negative'
    else:
        return 'Neutral'

# %%
reviews['review_grade'] = reviews['comments'].apply(sentiment_analyzer)

# %%
reviews['review_grade'].value_counts()
# Out:
# review_grade
# Positive    62995
# Neutral      3304
# Negative     1976
# Name: count, dtype: int64

# %%
reviews = reviews.rename(columns={'id':'review_id'})

# %%
reviews.columns
# Out:
# Index(['listing_id', 'review_id', 'date', 'reviewer_id', 'reviewer_name',
#        'comments', 'review_grade'],
#       dtype='object')

# %%
reviews['review_grade'].value_counts().index    #setting the order for the reviews
# Out:
# Index(['Positive', 'Neutral', 'Negative'], dtype='object', name='review_grade')

# %%
reviews_order = reviews['review_grade'].value_counts().index

# %%
plt.figure(figsize=(10,8.5))
sns.countplot(data=reviews, x='review_grade', order=reviews_order)
plt.title('Distribution of Listings\' Reviews')
plt.xlabel('Polarity of Review')
plt.ylabel('Polarity Count');

# %%
reviews.head(2)
# Out:
#    listing_id  review_id        date  reviewer_id reviewer_name  \
# 0     1178162    4724140  2013-05-21      4298113       Olivier
# 1     1178162    4869189  2013-05-29      6452964     Charlotte
#
#                                             comments review_grade
# 0  My stay at islam's place was really cool! Good...     Positive
# 1  Great location for both airport and city - gre...     Positive

# %%
listings.head(2)
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
#
#   last_scraped                               name  \
# 0   2016-09-07         Sunny Bungalow in the City
# 1   2016-09-07  Charming room in pet friendly apt
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...                 NaN
# 1  The room is in Roslindale, a diverse and prima...  ...                 9.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                t
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
#
#    reviews_per_month
# 0                NaN
# 1                1.3
#
# [2 rows x 95 columns]

# %% [markdown]
# Now we combine newreviews, listings and calendar on their common listing ID

# %%
df = reviews.merge(listings, left_on='listing_id', right_on='id', how='inner').drop(columns=['id', 'comments'])

#Dropping easily recognizable columns of shared id in listings

# %%
df.head(3)

#exploring nour newly created dataframe
# Out:
#    listing_id  review_id        date  reviewer_id reviewer_name review_grade  \
# 0     1178162    4724140  2013-05-21      4298113       Olivier     Positive
# 1     1178162    4869189  2013-05-29      6452964     Charlotte     Positive
# 2     1178162    5003196  2013-06-06      6449554     Sebastian     Positive
#
#                             listing_url       scrape_id last_scraped  \
# 0  https://www.airbnb.com/rooms/1178162  20160906204935   2016-09-07
# 1  https://www.airbnb.com/rooms/1178162  20160906204935   2016-09-07
# 2  https://www.airbnb.com/rooms/1178162  20160906204935   2016-09-07
#
#                                  name  ... review_scores_value  \
# 0  Private Room Great Location Boston  ...                 9.0
# 1  Private Room Great Location Boston  ...                 9.0
# 2  Private Room Great Location Boston  ...                 9.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                f
# 2                f     NaN                NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0              strict                             f
# 1              strict                             f
# 2              strict                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              4
# 1                                f                              4
# 2                                f                              4
#
#   reviews_per_month
# 0              5.35
# 1              5.35
# 2              5.35
#
# [3 rows x 100 columns]

# %%
df.info()

#further checks
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68275 entries, 0 to 68274
# Data columns (total 100 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   listing_id                        68275 non-null  int64
#  1   review_id                         68275 non-null  int64
#  2   date                              68275 non-null  object
#  3   reviewer_id                       68275 non-null  int64
#  4   reviewer_name                     68275 non-null  object
#  5   review_grade                      68275 non-null  object
#  6   listing_url                       68275 non-null  object
#  7   scrape_id                         68275 non-null  int64
#  8   last_scraped                      68275 non-null  object
#  9   name                              68275 non-null  object
#  10  summary                           62064 non-null  object
#  11  space                             60344 non-null  object
#  12  description                       68275 non-null  object
#  13  experiences_offered               68275 non-null  object
#  14  neighborhood_overview             50809 non-null  object
#  15  notes                             44818 non-null  object
#  16  transit                           53459 non-null  object
#  17  access                            52846 non-null  object
#  18  interaction                       50799 non-null  object
#  19  house_rules                       58246 non-null  object
#  20  thumbnail_url                     60370 non-null  object
#  21  medium_url                        60370 non-null  object
#  22  picture_url                       68275 non-null  object
#  23  xl_picture_url                    60370 non-null  object
#  24  host_id                           68275 non-null  int64
#  25  host_url                          68275 non-null  object
#  26  host_name                         68275 non-null  object
#  27  host_since                        68275 non-null  object
#  28  host_location                     68219 non-null  object
#  29  host_about                        56670 non-null  object
#  30  host_response_time                67163 non-null  object
#  31  host_response_rate                67163 non-null  object
#  32  host_acceptance_rate              67163 non-null  object
#  33  host_is_superhost                 68275 non-null  object
#  34  host_thumbnail_url                68275 non-null  object
#  35  host_picture_url                  68275 non-null  object
#  36  host_neighbourhood                64246 non-null  object
#  37  host_listings_count               68275 non-null  int64
#  38  host_total_listings_count         68275 non-null  int64
#  39  host_verifications                68275 non-null  object
#  40  host_has_profile_pic              68275 non-null  object
#  41  host_identity_verified            68275 non-null  object
#  42  street                            68275 non-null  object
#  43  neighbourhood                     60771 non-null  object
#  44  neighbourhood_cleansed            68275 non-null  object
#  45  neighbourhood_group_cleansed      0 non-null      float64
#  46  city                              68273 non-null  object
#  47  state                             68275 non-null  object
#  48  zipcode                           68076 non-null  object
#  49  market                            68250 non-null  object
#  50  smart_location                    68275 non-null  object
#  51  country_code                      68275 non-null  object
#  52  country                           68275 non-null  object
#  53  latitude                          68275 non-null  float64
#  54  longitude                         68275 non-null  float64
#  55  is_location_exact                 68275 non-null  object
#  56  property_type                     68247 non-null  object
#  57  room_type                         68275 non-null  object
#  58  accommodates                      68275 non-null  int64
#  59  bathrooms                         67510 non-null  float64
#  60  bedrooms                          68088 non-null  float64
#  61  beds                              68162 non-null  float64
#  62  bed_type                          68275 non-null  object
#  63  amenities                         68275 non-null  object
#  64  square_feet                       1783 non-null   float64
#  65  price                             68275 non-null  object
#  66  weekly_price                      27000 non-null  object
#  67  monthly_price                     25323 non-null  object
#  68  security_deposit                  30947 non-null  object
#  69  cleaning_fee                      46320 non-null  object
#  70  guests_included                   68275 non-null  int64
#  71  extra_people                      68275 non-null  object
#  72  minimum_nights                    68275 non-null  int64
#  73  maximum_nights                    68275 non-null  int64
#  74  calendar_updated                  68275 non-null  object
#  75  has_availability                  0 non-null      float64
#  76  availability_30                   68275 non-null  int64
#  77  availability_60                   68275 non-null  int64
#  78  availability_90                   68275 non-null  int64
#  79  availability_365                  68275 non-null  int64
#  80  calendar_last_scraped             68275 non-null  object
#  81  number_of_reviews                 68275 non-null  int64
#  82  first_review                      68275 non-null  object
#  83  last_review                       68275 non-null  object
#  84  review_scores_rating              68210 non-null  float64
#  85  review_scores_accuracy            68197 non-null  float64
#  86  review_scores_cleanliness         68202 non-null  float64
#  87  review_scores_checkin             68200 non-null  float64
#  88  review_scores_communication       68202 non-null  float64
#  89  review_scores_location            68197 non-null  float64
#  90  review_scores_value               68199 non-null  float64
#  91  requires_license                  68275 non-null  object
#  92  license                           0 non-null      float64
#  93  jurisdiction_names                0 non-null      float64
#  94  instant_bookable                  68275 non-null  object
#  95  cancellation_policy               68275 non-null  object
#  96  require_guest_profile_picture     68275 non-null  object
#  97  require_guest_phone_verification  68275 non-null  object
#  98  calculated_host_listings_count    68275 non-null  int64
#  99  reviews_per_month                 68275 non-null  float64
# dtypes: float64(18), int64(17), object(65)
# memory usage: 52.1+ MB

# %%
#accessing our columns help spot more column to drop, here, the basis is on the columns being homogenous

todrop = []
for col in df.select_dtypes(include='object').columns:
    if df[col].nunique() == 1:
        todrop.append(col)

# %%
#dropiing homogenous numerical columns

todropnum = []
for col in df.select_dtypes(include='number').columns:
    if df[col].nunique() == 1:
        todropnum.append(col)

# %%
todrop
# Out:
# ['last_scraped',
#  'experiences_offered',
#  'state',
#  'country_code',
#  'country',
#  'calendar_last_scraped',
#  'requires_license']

# %%
todropnum
# Out:
# ['scrape_id']

# %%
noneed = df.loc[:, df.isna().mean() == 1].columns

# %%
noneed
# Out:
# Index(['neighbourhood_group_cleansed', 'has_availability', 'license',
#        'jurisdiction_names'],
#       dtype='object')

# %%
df.isna().sum().sort_values(ascending=False).head(10)
# Out:
# has_availability                68275
# neighbourhood_group_cleansed    68275
# license                         68275
# jurisdiction_names              68275
# square_feet                     66492
# monthly_price                   42952
# weekly_price                    41275
# security_deposit                37328
# notes                           23457
# cleaning_fee                    21955
# dtype: int64

# %%
# plotting to see the distribution in non-homogenous columns that have the majority nans

plt.figure(figsize=(10,8.5))
df.loc[:, df.isna().mean() > 0.5].isna().sum().plot(kind='bar', rot=90, xlabel='Column', ylabel='Count Values', title='NA Counts for columns with more than half of their values missing');

# %%
#displaying na values in other columns(with less than half of their rows being nans)

plt.figure(figsize=(10,8.5))
df.loc[:, df.isna().mean() < 0.5].isna().sum().plot(kind='bar', rot=90, xlabel='Column', ylabel='Count Values', title='NA Counts for columns with less than half of their values missing');

# %% [markdown]
# ### dropping these columns:

# %%
df.drop(labels=todrop, axis=1, inplace=True) #about 7 columns would be dropped frpom our original 100

# %%
df.drop(labels=noneed, axis=1, inplace=True) #an additional 4 columns to be dropped

# %%
df.drop(labels=todropnum, axis=1, inplace=True) #an additional column to be dropped

# %%
df.shape #reaccessing our dataframe shape
# Out:
# (68275, 88)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68275 entries, 0 to 68274
# Data columns (total 88 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   listing_id                        68275 non-null  int64
#  1   review_id                         68275 non-null  int64
#  2   date                              68275 non-null  object
#  3   reviewer_id                       68275 non-null  int64
#  4   reviewer_name                     68275 non-null  object
#  5   review_grade                      68275 non-null  object
#  6   listing_url                       68275 non-null  object
#  7   name                              68275 non-null  object
#  8   summary                           62064 non-null  object
#  9   space                             60344 non-null  object
#  10  description                       68275 non-null  object
#  11  neighborhood_overview             50809 non-null  object
#  12  notes                             44818 non-null  object
#  13  transit                           53459 non-null  object
#  14  access                            52846 non-null  object
#  15  interaction                       50799 non-null  object
#  16  house_rules                       58246 non-null  object
#  17  thumbnail_url                     60370 non-null  object
#  18  medium_url                        60370 non-null  object
#  19  picture_url                       68275 non-null  object
#  20  xl_picture_url                    60370 non-null  object
#  21  host_id                           68275 non-null  int64
#  22  host_url                          68275 non-null  object
#  23  host_name                         68275 non-null  object
#  24  host_since                        68275 non-null  object
#  25  host_location                     68219 non-null  object
#  26  host_about                        56670 non-null  object
#  27  host_response_time                67163 non-null  object
#  28  host_response_rate                67163 non-null  object
#  29  host_acceptance_rate              67163 non-null  object
#  30  host_is_superhost                 68275 non-null  object
#  31  host_thumbnail_url                68275 non-null  object
#  32  host_picture_url                  68275 non-null  object
#  33  host_neighbourhood                64246 non-null  object
#  34  host_listings_count               68275 non-null  int64
#  35  host_total_listings_count         68275 non-null  int64
#  36  host_verifications                68275 non-null  object
#  37  host_has_profile_pic              68275 non-null  object
#  38  host_identity_verified            68275 non-null  object
#  39  street                            68275 non-null  object
#  40  neighbourhood                     60771 non-null  object
#  41  neighbourhood_cleansed            68275 non-null  object
#  42  city                              68273 non-null  object
#  43  zipcode                           68076 non-null  object
#  44  market                            68250 non-null  object
#  45  smart_location                    68275 non-null  object
#  46  latitude                          68275 non-null  float64
#  47  longitude                         68275 non-null  float64
#  48  is_location_exact                 68275 non-null  object
#  49  property_type                     68247 non-null  object
#  50  room_type                         68275 non-null  object
#  51  accommodates                      68275 non-null  int64
#  52  bathrooms                         67510 non-null  float64
#  53  bedrooms                          68088 non-null  float64
#  54  beds                              68162 non-null  float64
#  55  bed_type                          68275 non-null  object
#  56  amenities                         68275 non-null  object
#  57  square_feet                       1783 non-null   float64
#  58  price                             68275 non-null  object
#  59  weekly_price                      27000 non-null  object
#  60  monthly_price                     25323 non-null  object
#  61  security_deposit                  30947 non-null  object
#  62  cleaning_fee                      46320 non-null  object
#  63  guests_included                   68275 non-null  int64
#  64  extra_people                      68275 non-null  object
#  65  minimum_nights                    68275 non-null  int64
#  66  maximum_nights                    68275 non-null  int64
#  67  calendar_updated                  68275 non-null  object
#  68  availability_30                   68275 non-null  int64
#  69  availability_60                   68275 non-null  int64
#  70  availability_90                   68275 non-null  int64
#  71  availability_365                  68275 non-null  int64
#  72  number_of_reviews                 68275 non-null  int64
#  73  first_review                      68275 non-null  object
#  74  last_review                       68275 non-null  object
#  75  review_scores_rating              68210 non-null  float64
#  76  review_scores_accuracy            68197 non-null  float64
#  77  review_scores_cleanliness         68202 non-null  float64
#  78  review_scores_checkin             68200 non-null  float64
#  79  review_scores_communication       68202 non-null  float64
#  80  review_scores_location            68197 non-null  float64
#  81  review_scores_value               68199 non-null  float64
#  82  instant_bookable                  68275 non-null  object
#  83  cancellation_policy               68275 non-null  object
#  84  require_guest_profile_picture     68275 non-null  object
#  85  require_guest_phone_verification  68275 non-null  object
#  86  calculated_host_listings_count    68275 non-null  int64
#  87  reviews_per_month                 68275 non-null  float64
# dtypes: float64(14), int64(16), object(58)
# memory usage: 45.8+ MB

# %%
df['price']     #gradually exploring our target variable
# Out:
# 0        $95.00
# 1        $95.00
# 2        $95.00
# 3        $95.00
# 4        $95.00
#           ...
# 68270    $75.00
# 68271    $75.00
# 68272    $75.00
# 68273    $75.00
# 68274    $75.00
# Name: price, Length: 68275, dtype: object

# %%
df['price'].value_counts()
# Out:
# price
# $75.00       3378
# $99.00       3161
# $125.00      2897
# $65.00       2477
# $150.00      2396
#              ...
# $750.00         1
# $134.00         1
# $1,000.00       1
# $27.00          1
# $1,250.00       1
# Name: count, Length: 294, dtype: int64

# %%
df['price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 68275 entries, 0 to 68274
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 68275 non-null  object
# dtypes: object(1)
# memory usage: 533.5+ KB

# %%
df.columns
# Out:
# Index(['listing_id', 'review_id', 'date', 'reviewer_id', 'reviewer_name',
#        'review_grade', 'listing_url', 'name', 'summary', 'space',
#        'description', 'neighborhood_overview', 'notes', 'transit', 'access',
#        'interaction', 'house_rules', 'thumbnail_url', 'medium_url',
#        'picture_url', 'xl_picture_url', 'host_id', 'host_url', 'host_name',
#        'host_since', 'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed', 'city', 'zipcode',
#        'market', 'smart_location', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'number_of_reviews', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'instant_bookable', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# #### For easier undertstanding and analysis for a thorough visual inspection;

# %%
df.columns.sort_values(ascending=True)
# Out:
# Index(['access', 'accommodates', 'amenities', 'availability_30',
#        'availability_365', 'availability_60', 'availability_90', 'bathrooms',
#        'bed_type', 'bedrooms', 'beds', 'calculated_host_listings_count',
#        'calendar_updated', 'cancellation_policy', 'city', 'cleaning_fee',
#        'date', 'description', 'extra_people', 'first_review',
#        'guests_included', 'host_about', 'host_acceptance_rate',
#        'host_has_profile_pic', 'host_id', 'host_identity_verified',
#        'host_is_superhost', 'host_listings_count', 'host_location',
#        'host_name', 'host_neighbourhood', 'host_picture_url',
#        'host_response_rate', 'host_response_time', 'host_since',
#        'host_thumbnail_url', 'host_total_listings_count', 'host_url',
#        'host_verifications', 'house_rules', 'instant_bookable', 'interaction',
#        'is_location_exact', 'last_review', 'latitude', 'listing_id',
#        'listing_url', 'longitude', 'market', 'maximum_nights', 'medium_url',
#        'minimum_nights', 'monthly_price', 'name', 'neighborhood_overview',
#        'neighbourhood', 'neighbourhood_cleansed', 'notes', 'number_of_reviews',
#        'picture_url', 'price', 'property_type',
#        'require_guest_phone_verification', 'require_guest_profile_picture',
#        'review_grade', 'review_id', 'review_scores_accuracy',
#        'review_scores_checkin', 'review_scores_cleanliness',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_rating', 'review_scores_value', 'reviewer_id',
#        'reviewer_name', 'reviews_per_month', 'room_type', 'security_deposit',
#        'smart_location', 'space', 'square_feet', 'street', 'summary',
#        'thumbnail_url', 'transit', 'weekly_price', 'xl_picture_url',
#        'zipcode'],
#       dtype='object')

# %%
sorted_df = df.sort_index(axis=1)

# %%
sorted_df
# Out:
#                                                   access  accommodates  \
# 0                                                    NaN             2
# 1                                                    NaN             2
# 2                                                    NaN             2
# 3                                                    NaN             2
# 4                                                    NaN             2
# ...                                                  ...           ...
# 68270  1. House is cleaned by staff everyday. 2. Priv...             2
# 68271  1. House is cleaned by staff everyday. 2. Priv...             2
# 68272  1. House is cleaned by staff everyday. 2. Priv...             2
# 68273  1. House is cleaned by staff everyday. 2. Priv...             2
# 68274  1. House is cleaned by staff everyday. 2. Priv...             2
#
#                                                amenities  availability_30  \
# 0      {TV,"Cable TV",Internet,"Wireless Internet","A...                7
# 1      {TV,"Cable TV",Internet,"Wireless Internet","A...                7
# 2      {TV,"Cable TV",Internet,"Wireless Internet","A...                7
# 3      {TV,"Cable TV",Internet,"Wireless Internet","A...                7
# 4      {TV,"Cable TV",Internet,"Wireless Internet","A...                7
# ...                                                  ...              ...
# 68270  {TV,Internet,"Wireless Internet","Air Conditio...                0
# 68271  {TV,Internet,"Wireless Internet","Air Conditio...                0
# 68272  {TV,Internet,"Wireless Internet","Air Conditio...                0
# 68273  {TV,Internet,"Wireless Internet","Air Conditio...                0
# 68274  {TV,Internet,"Wireless Internet","Air Conditio...                0
#
#        availability_365  availability_60  availability_90  bathrooms  \
# 0                   342               37               67        1.0
# 1                   342               37               67        1.0
# 2                   342               37               67        1.0
# 3                   342               37               67        1.0
# 4                   342               37               67        1.0
# ...                 ...              ...              ...        ...
# 68270               290               11               15        2.0
# 68271               290               11               15        2.0
# 68272               290               11               15        2.0
# 68273               290               11               15        2.0
# 68274               290               11               15        2.0
#
#        bed_type  bedrooms  ...  smart_location  \
# 0         Futon       1.0  ...      Boston, MA
# 1         Futon       1.0  ...      Boston, MA
# 2         Futon       1.0  ...      Boston, MA
# 3         Futon       1.0  ...      Boston, MA
# 4         Futon       1.0  ...      Boston, MA
# ...         ...       ...  ...             ...
# 68270  Real Bed       1.0  ...      Boston, MA
# 68271  Real Bed       1.0  ...      Boston, MA
# 68272  Real Bed       1.0  ...      Boston, MA
# 68273  Real Bed       1.0  ...      Boston, MA
# 68274  Real Bed       1.0  ...      Boston, MA
#
#                                                    space square_feet  \
# 0      Great Boston Location conveniently located nea...         NaN
# 1      Great Boston Location conveniently located nea...         NaN
# 2      Great Boston Location conveniently located nea...         NaN
# 3      Great Boston Location conveniently located nea...         NaN
# 4      Great Boston Location conveniently located nea...         NaN
# ...                                                  ...         ...
# 68270  My location is close to a lot of attraction li...         NaN
# 68271  My location is close to a lot of attraction li...         NaN
# 68272  My location is close to a lot of attraction li...         NaN
# 68273  My location is close to a lot of attraction li...         NaN
# 68274  My location is close to a lot of attraction li...         NaN
#
#                                                  street  \
# 0      Saratoga Street, Boston, MA 02128, United States
# 1      Saratoga Street, Boston, MA 02128, United States
# 2      Saratoga Street, Boston, MA 02128, United States
# 3      Saratoga Street, Boston, MA 02128, United States
# 4      Saratoga Street, Boston, MA 02128, United States
# ...                                                 ...
# 68270        Hooker St, Boston, MA 02134, United States
# 68271        Hooker St, Boston, MA 02134, United States
# 68272        Hooker St, Boston, MA 02134, United States
# 68273        Hooker St, Boston, MA 02134, United States
# 68274        Hooker St, Boston, MA 02134, United States
#
#                                                  summary  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 68270  My place is close to Harvard Business School, ...
# 68271  My place is close to Harvard Business School, ...
# 68272  My place is close to Harvard Business School, ...
# 68273  My place is close to Harvard Business School, ...
# 68274  My place is close to Harvard Business School, ...
#
#                                            thumbnail_url transit weekly_price  \
# 0      https://a2.muscache.com/im/pictures/19b75f9c-e...     NaN      $550.00
# 1      https://a2.muscache.com/im/pictures/19b75f9c-e...     NaN      $550.00
# 2      https://a2.muscache.com/im/pictures/19b75f9c-e...     NaN      $550.00
# 3      https://a2.muscache.com/im/pictures/19b75f9c-e...     NaN      $550.00
# 4      https://a2.muscache.com/im/pictures/19b75f9c-e...     NaN      $550.00
# ...                                                  ...     ...          ...
# 68270  https://a0.muscache.com/im/pictures/94705214/d...     NaN      $395.00
# 68271  https://a0.muscache.com/im/pictures/94705214/d...     NaN      $395.00
# 68272  https://a0.muscache.com/im/pictures/94705214/d...     NaN      $395.00
# 68273  https://a0.muscache.com/im/pictures/94705214/d...     NaN      $395.00
# 68274  https://a0.muscache.com/im/pictures/94705214/d...     NaN      $395.00
#
#                                           xl_picture_url zipcode
# 0      https://a2.muscache.com/im/pictures/19b75f9c-e...   02128
# 1      https://a2.muscache.com/im/pictures/19b75f9c-e...   02128
# 2      https://a2.muscache.com/im/pictures/19b75f9c-e...   02128
# 3      https://a2.muscache.com/im/pictures/19b75f9c-e...   02128
# 4      https://a2.muscache.com/im/pictures/19b75f9c-e...   02128
# ...                                                  ...     ...
# 68270  https://a0.muscache.com/im/pictures/94705214/d...   02134
# 68271  https://a0.muscache.com/im/pictures/94705214/d...   02134
# 68272  https://a0.muscache.com/im/pictures/94705214/d...   02134
# 68273  https://a0.muscache.com/im/pictures/94705214/d...   02134
# 68274  https://a0.muscache.com/im/pictures/94705214/d...   02134
#
# [68275 rows x 88 columns]

# %%
df.columns.sort_values()
# Out:
# Index(['access', 'accommodates', 'amenities', 'availability_30',
#        'availability_365', 'availability_60', 'availability_90', 'bathrooms',
#        'bed_type', 'bedrooms', 'beds', 'calculated_host_listings_count',
#        'calendar_updated', 'cancellation_policy', 'city', 'cleaning_fee',
#        'date', 'description', 'extra_people', 'first_review',
#        'guests_included', 'host_about', 'host_acceptance_rate',
#        'host_has_profile_pic', 'host_id', 'host_identity_verified',
#        'host_is_superhost', 'host_listings_count', 'host_location',
#        'host_name', 'host_neighbourhood', 'host_picture_url',
#        'host_response_rate', 'host_response_time', 'host_since',
#        'host_thumbnail_url', 'host_total_listings_count', 'host_url',
#        'host_verifications', 'house_rules', 'instant_bookable', 'interaction',
#        'is_location_exact', 'last_review', 'latitude', 'listing_id',
#        'listing_url', 'longitude', 'market', 'maximum_nights', 'medium_url',
#        'minimum_nights', 'monthly_price', 'name', 'neighborhood_overview',
#        'neighbourhood', 'neighbourhood_cleansed', 'notes', 'number_of_reviews',
#        'picture_url', 'price', 'property_type',
#        'require_guest_phone_verification', 'require_guest_profile_picture',
#        'review_grade', 'review_id', 'review_scores_accuracy',
#        'review_scores_checkin', 'review_scores_cleanliness',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_rating', 'review_scores_value', 'reviewer_id',
#        'reviewer_name', 'reviews_per_month', 'room_type', 'security_deposit',
#        'smart_location', 'space', 'square_feet', 'street', 'summary',
#        'thumbnail_url', 'transit', 'weekly_price', 'xl_picture_url',
#        'zipcode'],
#       dtype='object')

# %%
furtherinv = []
for col in df.columns: #checking cardinality of columns
    if df[col].value_counts().count() > 5:
        furtherinv.append(col)

# %%
furtherinv     #displaying highly cardinal columns
# Out:
# ['listing_id',
#  'review_id',
#  'date',
#  'reviewer_id',
#  'reviewer_name',
#  'listing_url',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'city',
#  'zipcode',
#  'smart_location',
#  'latitude',
#  'longitude',
#  'property_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'calendar_updated',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'number_of_reviews',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'calculated_host_listings_count',
#  'reviews_per_month']

# %%
df['reviews_per_month'].value_counts()
# Out:
# reviews_per_month
# 3.86    501
# 3.75    494
# 6.23    451
# 5.85    447
# 7.05    443
#        ...
# 4.77      7
# 2.43      6
# 5.29      6
# 0.02      2
# 0.01      1
# Name: count, Length: 644, dtype: int64

# %%
def find_dollar_sign(df):
    '''To expose columns with $ in their values'''
    # Iterate through each column in the DataFrame
    for col in df.columns:
        # Check if any value in the column contains a dollar sign using regex
        if df[col].astype(str).str.contains(r'\$', regex=True).any():
            print(f"Dollar sign found in column: {col}")

# %%
find_dollar_sign(df)
# Out:
# Dollar sign found in column: name
# Dollar sign found in column: summary
# Dollar sign found in column: space
# Dollar sign found in column: description
# Dollar sign found in column: neighborhood_overview
# Dollar sign found in column: notes
# Dollar sign found in column: transit
# Dollar sign found in column: access
# Dollar sign found in column: interaction
# Dollar sign found in column: house_rules
# Dollar sign found in column: host_about
# Dollar sign found in column: price
# Dollar sign found in column: weekly_price
# Dollar sign found in column: monthly_price
# Dollar sign found in column: security_deposit
# Dollar sign found in column: cleaning_fee
# Dollar sign found in column: extra_people

# %%
df['security_deposit'].value_counts()
# Out:
# security_deposit
# $100.00      11321
# $500.00       3935
# $200.00       3288
# $300.00       2837
# $250.00       2524
# $150.00       2460
# $400.00       1141
# $95.00         539
# $350.00        532
# $1,000.00      368
# $125.00        268
# $600.00        249
# $99.00         172
# $450.00        161
# $1,500.00      117
# $399.00         85
# $325.00         83
# $301.00         73
# $180.00         65
# $275.00         64
# $750.00         63
# $800.00         63
# $425.00         62
# $199.00         56
# $185.00         52
# $179.00         48
# $375.00         36
# $2,500.00       30
# $475.00         30
# $299.00         29
# $3,000.00       27
# $446.00         26
# $2,000.00       23
# $4,000.00       22
# $650.00         20
# $1,250.00       12
# $1,900.00        9
# $220.00          7
# $120.00          7
# $4,500.00        7
# $160.00          6
# $298.00          6
# $147.00          6
# $700.00          6
# $223.00          3
# $330.00          3
# $128.00          2
# $950.00          2
# $1,200.00        1
# $175.00          1
# Name: count, dtype: int64

# %%
def extract_dollar_values(df):
    '''Function to extract dollar values in columns'''
    def extract_and_convert(value):
        if pd.isna(value) or value == '':
            return pd.NA
        if isinstance(value, str):
            # Extract numbers, including negative signs and decimal points
            match = re.search(r'-?\$?(\d+(?:\.\d+)?)', value)
            if match:
                return float(match.group(1))
        return value

    for column in df.columns:
        if df[column].dtype == 'object' and df[column].str.contains(r'\$|\d', na=False).any():
            df[column] = df[column].apply(extract_and_convert)
    
    return df

# %%
extract_dollar_values(df)  #running our extacrting function
# Out:
#        listing_id  review_id    date  reviewer_id reviewer_name review_grade  \
# 0         1178162    4724140  2013.0      4298113       Olivier     Positive
# 1         1178162    4869189  2013.0      6452964     Charlotte     Positive
# 2         1178162    5003196  2013.0      6449554     Sebastian     Positive
# 3         1178162    5150351  2013.0      2215611        Marine     Positive
# 4         1178162    5171140  2013.0      6848427        Andrew     Positive
# ...           ...        ...     ...          ...           ...          ...
# 68270     7462268   80537457  2016.0     22034145       Antonio     Positive
# 68271     7462268   83640094  2016.0     40052513         Steve     Positive
# 68272     7462268   85797088  2016.0     77129134          Nick     Positive
# 68273     7462268   97264637  2016.0     15799803           Vid     Positive
# 68274     7462268   98550693  2016.0     90128094       Arianna     Positive
#
#        listing_url                                              name summary  \
# 0        1178162.0                Private Room Great Location Boston    <NA>
# 1        1178162.0                Private Room Great Location Boston    <NA>
# 2        1178162.0                Private Room Great Location Boston    <NA>
# 3        1178162.0                Private Room Great Location Boston    <NA>
# 4        1178162.0                Private Room Great Location Boston    <NA>
# ...            ...                                               ...     ...
# 68270    7462268.0  Allston, close to Harvard Business School + BU D     5.0
# 68271    7462268.0  Allston, close to Harvard Business School + BU D     5.0
# 68272    7462268.0  Allston, close to Harvard Business School + BU D     5.0
# 68273    7462268.0  Allston, close to Harvard Business School + BU D     5.0
# 68274    7462268.0  Allston, close to Harvard Business School + BU D     5.0
#
#       space  ... review_scores_checkin review_scores_communication  \
# 0       6.0  ...                   9.0                         9.0
# 1       6.0  ...                   9.0                         9.0
# 2       6.0  ...                   9.0                         9.0
# 3       6.0  ...                   9.0                         9.0
# 4       6.0  ...                   9.0                         9.0
# ...     ...  ...                   ...                         ...
# 68270  40.0  ...                  10.0                        10.0
# 68271  40.0  ...                  10.0                        10.0
# 68272  40.0  ...                  10.0                        10.0
# 68273  40.0  ...                  10.0                        10.0
# 68274  40.0  ...                  10.0                        10.0
#
#       review_scores_location review_scores_value instant_bookable  \
# 0                        8.0                 9.0                f
# 1                        8.0                 9.0                f
# 2                        8.0                 9.0                f
# 3                        8.0                 9.0                f
# 4                        8.0                 9.0                f
# ...                      ...                 ...              ...
# 68270                    9.0                10.0                t
# 68271                    9.0                10.0                t
# 68272                    9.0                10.0                t
# 68273                    9.0                10.0                t
# 68274                    9.0                10.0                t
#
#       cancellation_policy require_guest_profile_picture  \
# 0                  strict                             f
# 1                  strict                             f
# 2                  strict                             f
# 3                  strict                             f
# 4                  strict                             f
# ...                   ...                           ...
# 68270            flexible                             f
# 68271            flexible                             f
# 68272            flexible                             f
# 68273            flexible                             f
# 68274            flexible                             f
#
#       require_guest_phone_verification calculated_host_listings_count  \
# 0                                    f                              4
# 1                                    f                              4
# 2                                    f                              4
# 3                                    f                              4
# 4                                    f                              4
# ...                                ...                            ...
# 68270                                f                              8
# 68271                                f                              8
# 68272                                f                              8
# 68273                                f                              8
# 68274                                f                              8
#
#        reviews_per_month
# 0                   5.35
# 1                   5.35
# 2                   5.35
# 3                   5.35
# 4                   5.35
# ...                  ...
# 68270               2.32
# 68271               2.32
# 68272               2.32
# 68273               2.32
# 68274               2.32
#
# [68275 rows x 88 columns]

# %%
to_num = ['price','security_deposit','cleaning_fee','extra_people']

# %%
df[to_num]
# Out:
#        price security_deposit cleaning_fee  extra_people
# 0       95.0            100.0          NaN           0.0
# 1       95.0            100.0          NaN           0.0
# 2       95.0            100.0          NaN           0.0
# 3       95.0            100.0          NaN           0.0
# 4       95.0            100.0          NaN           0.0
# ...      ...              ...          ...           ...
# 68270   75.0            100.0         35.0           0.0
# 68271   75.0            100.0         35.0           0.0
# 68272   75.0            100.0         35.0           0.0
# 68273   75.0            100.0         35.0           0.0
# 68274   75.0            100.0         35.0           0.0
#
# [68275 rows x 4 columns]

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df['security_deposit'] = pd.to_numeric(df['security_deposit'], errors='coerce')
df['cleaning_fee'] = pd.to_numeric(df['cleaning_fee'], errors='coerce')
df['extra_people'] = pd.to_numeric(df['extra_people'], errors='coerce')

#hard converting numeric columns

# %%
df.select_dtypes(include='number').columns.sort_values()
# Out:
# Index(['accommodates', 'availability_30', 'availability_365',
#        'availability_60', 'availability_90', 'bathrooms', 'bedrooms', 'beds',
#        'calculated_host_listings_count', 'cleaning_fee', 'date',
#        'extra_people', 'first_review', 'guests_included', 'host_id',
#        'host_listings_count', 'host_picture_url', 'host_since',
#        'host_thumbnail_url', 'host_total_listings_count', 'host_url',
#        'last_review', 'latitude', 'listing_id', 'listing_url', 'longitude',
#        'maximum_nights', 'minimum_nights', 'number_of_reviews', 'picture_url',
#        'price', 'review_id', 'review_scores_accuracy', 'review_scores_checkin',
#        'review_scores_cleanliness', 'review_scores_communication',
#        'review_scores_location', 'review_scores_rating', 'review_scores_value',
#        'reviewer_id', 'reviews_per_month', 'security_deposit', 'square_feet'],
#       dtype='object')

# %%
df['transit'].value_counts()    #upon inspection, we see some messy data in this coulmn
# Out:
# transit
# 5.0                                                                                                                                                                                                                                                                                                                                                  7592
# 10.0                                                                                                                                                                                                                                                                                                                                                 6524
# 2.0                                                                                                                                                                                                                                                                                                                                                  3488
# 3.0                                                                                                                                                                                                                                                                                                                                                  3026
# 1.0                                                                                                                                                                                                                                                                                                                                                  1924
#                                                                                                                                                                                                                                                                                                                                                      ...
# Easily accessible via the red line, commuter train, bus lines and car.                                                                                                                                                                                                                                                                                  1
# There are buses that stop right in front of the house and down the street. We are a convenient bus ride away from the forest hills MBTA stop which is the subway system in Boston. There's free street parking all around the house should you have a car.                                                                                              1
# We are a ten minute walk from the MBTA Orange Line (Massachusetts Avenue Station), and one minute from the Silver Line and other frequently running buses. Hubway shared bicycles (rent by hour or day) line both of the main streets perpendicular to ours. And being just minutes from several major streets means plenty of cabs day or night.       1
# Several bus stops within blocks, and located one mile from the Red Line.                                                                                                                                                                                                                                                                                1
# The MBTA or the “T” as locals call it, is our subway system. The closest T stop to our building is Copley Square Stop (Green Line).  For more information visit (URL HIDDEN)                                                                                                                                                                            1
# Name: count, Length: 533, dtype: int64

# %% [markdown]
# ### Feature Selection
#
# What we actually do here is to select columns to be used for our Machine Learning Model

# %%
hz = df[[
    'availability_30',
    'cancellation_policy', 'instant_bookable', 'minimum_nights', 'maximum_nights',
    'bathrooms', 'bed_type', 'bedrooms', 'beds', 'cleaning_fee', 'guests_included',
    'property_type', 'room_type', 'square_feet', 'city', 'latitude', 'longitude',
    'neighbourhood', 'neighbourhood_cleansed', 'zipcode', 'host_acceptance_rate',
    'host_is_superhost', 'host_listings_count',
    'host_response_time', 'host_total_listings_count', 'number_of_reviews', 'review_scores_accuracy', 'price', 'security_deposit',
    'extra_people'
]]

# %%
hz
# Out:
#        availability_30 cancellation_policy instant_bookable  minimum_nights  \
# 0                    7              strict                f               1
# 1                    7              strict                f               1
# 2                    7              strict                f               1
# 3                    7              strict                f               1
# 4                    7              strict                f               1
# ...                ...                 ...              ...             ...
# 68270                0            flexible                t               1
# 68271                0            flexible                t               1
# 68272                0            flexible                t               1
# 68273                0            flexible                t               1
# 68274                0            flexible                t               1
#
#        maximum_nights  bathrooms  bed_type  bedrooms  beds  cleaning_fee  ...  \
# 0                1125        1.0     Futon       1.0   1.0           NaN  ...
# 1                1125        1.0     Futon       1.0   1.0           NaN  ...
# 2                1125        1.0     Futon       1.0   1.0           NaN  ...
# 3                1125        1.0     Futon       1.0   1.0           NaN  ...
# 4                1125        1.0     Futon       1.0   1.0           NaN  ...
# ...               ...        ...       ...       ...   ...           ...  ...
# 68270            1125        2.0  Real Bed       1.0   1.0          35.0  ...
# 68271            1125        2.0  Real Bed       1.0   1.0          35.0  ...
# 68272            1125        2.0  Real Bed       1.0   1.0          35.0  ...
# 68273            1125        2.0  Real Bed       1.0   1.0          35.0  ...
# 68274            1125        2.0  Real Bed       1.0   1.0          35.0  ...
#
#        host_acceptance_rate host_is_superhost host_listings_count  \
# 0                      97.0                 f                   4
# 1                      97.0                 f                   4
# 2                      97.0                 f                   4
# 3                      97.0                 f                   4
# 4                      97.0                 f                   4
# ...                     ...               ...                 ...
# 68270                 100.0                 f                   8
# 68271                 100.0                 f                   8
# 68272                 100.0                 f                   8
# 68273                 100.0                 f                   8
# 68274                 100.0                 f                   8
#
#        host_response_time host_total_listings_count  number_of_reviews  \
# 0          within an hour                         4                215
# 1          within an hour                         4                215
# 2          within an hour                         4                215
# 3          within an hour                         4                215
# 4          within an hour                         4                215
# ...                   ...                       ...                ...
# 68270      within an hour                         8                 32
# 68271      within an hour                         8                 32
# 68272      within an hour                         8                 32
# 68273      within an hour                         8                 32
# 68274      within an hour                         8                 32
#
#        review_scores_accuracy price security_deposit extra_people
# 0                         9.0  95.0            100.0          0.0
# 1                         9.0  95.0            100.0          0.0
# 2                         9.0  95.0            100.0          0.0
# 3                         9.0  95.0            100.0          0.0
# 4                         9.0  95.0            100.0          0.0
# ...                       ...   ...              ...          ...
# 68270                    10.0  75.0            100.0          0.0
# 68271                    10.0  75.0            100.0          0.0
# 68272                    10.0  75.0            100.0          0.0
# 68273                    10.0  75.0            100.0          0.0
# 68274                    10.0  75.0            100.0          0.0
#
# [68275 rows x 30 columns]

# %%
hz['host_duration'] = 2024-df['host_since']     #creating new column for age of host's hostings :)

# %%
hz['host_duration']= hz['host_duration'].astype('int8')    #type conversion

# %%
hz['host_duration']     #validatiing host duration age
# Out:
# 0        13
# 1        13
# 2        13
# 3        13
# 4        13
#          ..
# 68270    10
# 68271    10
# 68272    10
# 68273    10
# 68274    10
# Name: host_duration, Length: 68275, dtype: int8

# %%
hz.columns      #verifyingdataframe
# Out:
# Index(['availability_30', 'cancellation_policy', 'instant_bookable',
#        'minimum_nights', 'maximum_nights', 'bathrooms', 'bed_type', 'bedrooms',
#        'beds', 'cleaning_fee', 'guests_included', 'property_type', 'room_type',
#        'square_feet', 'city', 'latitude', 'longitude', 'neighbourhood',
#        'neighbourhood_cleansed', 'zipcode', 'host_acceptance_rate',
#        'host_is_superhost', 'host_listings_count', 'host_response_time',
#        'host_total_listings_count', 'number_of_reviews',
#        'review_scores_accuracy', 'price', 'security_deposit', 'extra_people',
#        'host_duration'],
#       dtype='object')

# %%
hz.head()      #accessing ML dependent dataframe
# Out:
#    availability_30 cancellation_policy instant_bookable  minimum_nights  \
# 0                7              strict                f               1
# 1                7              strict                f               1
# 2                7              strict                f               1
# 3                7              strict                f               1
# 4                7              strict                f               1
#
#    maximum_nights  bathrooms bed_type  bedrooms  beds  cleaning_fee  ...  \
# 0            1125        1.0    Futon       1.0   1.0           NaN  ...
# 1            1125        1.0    Futon       1.0   1.0           NaN  ...
# 2            1125        1.0    Futon       1.0   1.0           NaN  ...
# 3            1125        1.0    Futon       1.0   1.0           NaN  ...
# 4            1125        1.0    Futon       1.0   1.0           NaN  ...
#
#    host_is_superhost host_listings_count host_response_time  \
# 0                  f                   4     within an hour
# 1                  f                   4     within an hour
# 2                  f                   4     within an hour
# 3                  f                   4     within an hour
# 4                  f                   4     within an hour
#
#    host_total_listings_count number_of_reviews  review_scores_accuracy  price  \
# 0                          4               215                     9.0   95.0
# 1                          4               215                     9.0   95.0
# 2                          4               215                     9.0   95.0
# 3                          4               215                     9.0   95.0
# 4                          4               215                     9.0   95.0
#
#   security_deposit extra_people host_duration
# 0            100.0          0.0            13
# 1            100.0          0.0            13
# 2            100.0          0.0            13
# 3            100.0          0.0            13
# 4            100.0          0.0            13
#
# [5 rows x 31 columns]

# %%
hz.info()     #accessing ML dependent dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68275 entries, 0 to 68274
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   availability_30            68275 non-null  int64
#  1   cancellation_policy        68275 non-null  object
#  2   instant_bookable           68275 non-null  object
#  3   minimum_nights             68275 non-null  int64
#  4   maximum_nights             68275 non-null  int64
#  5   bathrooms                  67510 non-null  float64
#  6   bed_type                   68275 non-null  object
#  7   bedrooms                   68088 non-null  float64
#  8   beds                       68162 non-null  float64
#  9   cleaning_fee               46320 non-null  float64
#  10  guests_included            68275 non-null  int64
#  11  property_type              68247 non-null  object
#  12  room_type                  68275 non-null  object
#  13  square_feet                1783 non-null   float64
#  14  city                       68273 non-null  object
#  15  latitude                   68275 non-null  float64
#  16  longitude                  68275 non-null  float64
#  17  neighbourhood              60771 non-null  object
#  18  neighbourhood_cleansed     68275 non-null  object
#  19  zipcode                    68076 non-null  object
#  20  host_acceptance_rate       67163 non-null  object
#  21  host_is_superhost          68275 non-null  object
#  22  host_listings_count        68275 non-null  int64
#  23  host_response_time         67163 non-null  object
#  24  host_total_listings_count  68275 non-null  int64
#  25  number_of_reviews          68275 non-null  int64
#  26  review_scores_accuracy     68197 non-null  float64
#  27  price                      68275 non-null  float64
#  28  security_deposit           30947 non-null  float64
#  29  extra_people               68275 non-null  float64
#  30  host_duration              68275 non-null  int8
# dtypes: float64(11), int64(7), int8(1), object(12)
# memory usage: 15.7+ MB

# %% [markdown]
# # SECTION IV: EXPLORATORY DATA ANALYSIS

# %% [markdown]
# #### Exploratory Data Analysis refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations. We are going to be exploring the data with these questions in mind

# %% [markdown]
# #####
# * What factors are important to know, the ones that really determine the price for AirBnb listings
# * How do these factors vary

# %% [markdown]
# ## 1. Target Variable EDA

# %% [markdown]
# __price__, being our targevet, we aim to visualize it in details

# %%
bin = np.arange(0, hz['price'].max()+15, 15)

# %%
color=sns.color_palette()[0]

# %%
plt.figure(figsize=(10,8.5))
sns.histplot(data=hz, x='price', bins=bin, alpha=0.9, color=color)
plt.xticks(np.arange(0, 900, 100))
plt.title('Overall count of Airbnb Prices')
plt.xlabel('Price');     #using a histplot to view the distribution of prices

# %% [markdown]
# * The skew tells us so many info really, we see the peak right before the 100th mark.
# * Really that skew shows other different prices we get, but the count show how few they are

# %%
plt.figure(figsize=(10,8.5))
sns.kdeplot(hz['price'], shade=True)
plt.title('Density Plot of Airbnb Prices')
plt.xlabel('Price')
plt.xticks(np.arange(0,900,100))
plt.ylabel('Density')     #showing continous probability of the price data
# Out:
# Text(0, 0.5, 'Density')

# %%
plt.figure(figsize=(10,8.5))
sns.boxplot(x=hz['price'])
plt.title('Box Plot of Airbnb Prices')
plt.xlabel('Price')
plt.xticks(np.arange(0,900,100))
plt.show()   #box plot for further inspection

# %% [markdown]
# Breaking the plots down;
#
# * Mode: We have the mostr prices at around 70
# * Median: Our box plot here shows our median to be about 110$ thereabout. This is greatly influenced by the outliers.
# * Interquartile Rnage: a range of about 70 to nearly 200, shows where our majority of prices are
# * Whiskers: The whiskers, especially the one to the right, shows at what value we start considering prices to be outliers
# * Outliers: Outliers ranging from 330 thereabout to 800+, showing higher prices than majority

# %% [markdown]
# ## 2. Univariate EDA

# %% [markdown]
# We will observe the trends by cheching the proportion in each variable

# %%
def plot_order(col):
    '''Function to give order to plots'''
    return hz[col].value_counts().index

# %%
plt.figure(figsize=(10,8.5))
sns.countplot(data=hz, x='host_duration', order=plot_order('host_duration'))
plt.title('Host Duration Countpllot');        #counting values in 'host_duration'

# %%
plt.figure(figsize=(10,8.5))
sns.countplot(data=hz, x='instant_bookable')
plt.title('Instant booking Countplot');      #counting values in 'instant_bookable'

# %%
plt.figure(figsize=(10,8.5))
sns.countplot(data=hz, x='host_response_time', order=plot_order('host_response_time'))#counting 'response_time' according to listing
plt.xticks(rotation=0)
plt.xlabel('Different Host Response Times')
plt.ylabel('Count of Responses')
plt.title('Host Response Time Plot');

# %%
plt.figure(figsize=(10,8.5))
sns.countplot(data=hz, x='host_is_superhost')
plt.title('SUperhost Plot');        #superhost count

# %%
plt.figure(figsize=(10,8.5))
sns.countplot(data=hz, x='beds', order=plot_order('beds'))
plt.title('Distribution of Beds in listing');   #showing distribution of beds

# %%
hz['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    36104
# Private room       31306
# Shared room          865
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=hz, x='room_type', order=plot_order('room_type'))      #distribution of roomtypes
plt.yticks(np.arange(0, 36000, 5000))
plt.xlabel('Rental Property Type')
plt.ylabel('Property Count')
plt.title('Rental Property Plot');

# %%
hz['bed_type'].value_counts()
# Out:
# bed_type
# Real Bed         66023
# Futon             1116
# Pull-out Sofa      600
# Airbed             474
# Couch               62
# Name: count, dtype: int64

# %%
color=sns.color_palette()[0]

# %%
plt.figure(figsize=(10,8.5))
sns.countplot(data=hz, x='bed_type', color=color, order=plot_order('bed_type'))
plt.title('Bed type count data');         #different 'bed_type' variations

# %%
hz['property_type'].value_counts()
# Out:
# property_type
# Apartment          44553
# House              16997
# Condominium         3339
# Bed & Breakfast     1437
# Townhouse            880
# Loft                 730
# Boat                 187
# Other                 64
# Villa                 33
# Dorm                  25
# Entire Floor           1
# Guesthouse             1
# Name: count, dtype: int64

# %%
hz['neighbourhood_cleansed'].value_counts()
# Out:
# neighbourhood_cleansed
# Jamaica Plain              9055
# Dorchester                 7396
# South End                  5714
# East Boston                5504
# North End                  4483
# Back Bay                   4389
# Beacon Hill                4098
# South Boston               3851
# Roxbury                    3775
# Brighton                   3052
# Allston                    2988
# Fenway                     2817
# Downtown                   2535
# Charlestown                1981
# Mission Hill               1469
# Roslindale                 1387
# South Boston Waterfront     744
# West Roxbury                690
# Chinatown                   669
# Mattapan                    442
# Longwood Medical Area       393
# Hyde Park                   376
# Bay Village                 241
# West End                    157
# Leather District             69
# Name: count, dtype: int64

# %%
hz['price'].value_counts()
# Out:
# price
# 75.0     3378
# 99.0     3161
# 125.0    2897
# 65.0     2477
# 150.0    2396
#          ...
# 750.0       1
# 625.0       1
# 20.0        1
# 536.0       1
# 570.0       1
# Name: count, Length: 292, dtype: int64

# %%
hz['bedrooms'].value_counts()
# Out:
# bedrooms
# 1.0    48864
# 2.0     9800
# 0.0     5568
# 3.0     2668
# 4.0      978
# 5.0      210
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8.5))
sns.countplot(data=hz, x='bedrooms', color=color, order=plot_order('bedrooms'))
plt.title('Bed per listing plot');

# %%
hz['city'].value_counts().head(10)
# Out:
# city
# Boston              62350
# Dorchester           1684
# Brighton              773
# Jamaica Plain         616
# Charlestown           595
# Allston               413
# Roslindale            290
# East Boston           263
# Roxbury Crossing      230
# South Boston          142
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8.5))
hz['city'].value_counts().head(10).plot(kind='bar');        #visualising distribution of cities and their listings

# %%
plt.figure(figsize=(10,8.5))
hz['neighbourhood'].value_counts().head(10).plot(kind='bar') 
plt.title('Top 10 Neighbourhoods for the AirBnB data')
plt.xlabel('Neighbourhood')
plt.ylabel('Neighbourhood counts'); #these are the neighbourhopds with the most listings

# %% [markdown]
# #### Univariate Insights:
#
# * Most listings are 1 beds, surprisingly there’s a 16 bed listing
# * Entire apartments are what are offered the most
# * People resoundingly use real beds more
# * 1 bedrooms mostly, rather than 2 are posted

# %% [markdown]
# ## 3. Bivariate EDA

# %% [markdown]
# Here, we aim to explore relationship between variables and the other

# %%
hz.select_dtypes(include='object').info()            #visulaizing all Categorical columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68275 entries, 0 to 68274
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   cancellation_policy     68275 non-null  object
#  1   instant_bookable        68275 non-null  object
#  2   bed_type                68275 non-null  object
#  3   property_type           68247 non-null  object
#  4   room_type               68275 non-null  object
#  5   city                    68273 non-null  object
#  6   neighbourhood           60771 non-null  object
#  7   neighbourhood_cleansed  68275 non-null  object
#  8   zipcode                 68076 non-null  object
#  9   host_acceptance_rate    67163 non-null  object
#  10  host_is_superhost       68275 non-null  object
#  11  host_response_time      67163 non-null  object
# dtypes: object(12)
# memory usage: 6.3+ MB

# %%
plt.figure(figsize=(10,8.5))
sns.boxplot(data=hz, y='price', x='room_type')
plt.title('Price to Roomtype Distribution Boxplot');               #seeing relationship between room_type and price

# %%
plt.figure(figsize=(10,8.5))
sns.boxplot(data=hz, y='price', x='property_type')                  #visualizing relationship between property_type and price   
plt.xticks(rotation=90)
plt.title('Price to Propertytype Distribution Boxplot');

# %%
plt.figure(figsize=(10,8.5))
sns.regplot(data=hz, x='price', y='security_deposit')
plt.title('Price vs Deposit correlation');

# %%
plt.figure(figsize=(10,8.5))
sns.regplot(data=hz, x='security_deposit', y='extra_people');         #exploring how host's deposit is affected by extra guests

# %%
plt.figure(figsize=(10,8.5))
sns.regplot(data=hz, x='price', y='extra_people');            #exploring how price is affected by extra guests

# %%
plt.figure(figsize=(10,8.5))
sns.regplot(data=hz, x='beds', y='price');         #visualizing how price is affected by no_of beds

# %%
plt.figure(figsize=(10,8.5))
sns.boxplot(data=hz, y='price', x='instant_bookable');

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=hz, x='room_type', hue='bed_type')
plt.xlabel('Rental Property Subdivision')
plt.ylabel('Count of Distribution')
plt.title('Apartment Types and their Bed Type Distributions');          #very curiously I examine the distribution of bed types in different lsitings

# %% [markdown]
# #### Bivariate Insights:
#
# * Not surprisingly, apartments have the largest prices
# * This means that, generally, as the security_deposit increases, the price also tends to increase
# * Although there is, it is a very weak positive relationship between security_deposit and extra_people.
# * Number of beds determines price greatly
# * Highest prices aren’t instantly bookable
# * Entire apartments, just like every other kind prefer real bed

# %% [markdown]
# ## 4. Multivariate EDA

# %% [markdown]
# Studying how the variables relate with one another and how they can help in predicting the target variable. How do the variables affect each other(Correlation) and affects the target variable.

# %% [markdown]
# Price vs Roomtype and ExtraPeople

# %% [markdown]
# Price vs Beds and InstantBookable

# %% [markdown]
# Plotting a correlelogram

# %%
#Facetting
g = sns.FacetGrid(data=hz, col='instant_bookable')
g.map(sns.regplot, 'price', 'beds')

# %%
g = sns.FacetGrid(data=hz, col='room_type')
g.map(sns.regplot, 'price', 'extra_people')

# %%
le = LabelEncoder()

# %%
hist2ddf = hz.copy()     #copying for a correlelogram

# %%
for col in hist2ddf.select_dtypes(include='object'):    
    hist2ddf[col] = le.fit_transform(hist2ddf[col].astype(str))

# %%
hist2ddf.select_dtypes(include='object').columns
# Out:
# Index([], dtype='object')

# %%
hist2ddf.corr()
# Out:
#                            availability_30  cancellation_policy  \
# availability_30                   1.000000             0.091214
# cancellation_policy               0.091214             1.000000
# instant_bookable                  0.005555             0.013951
# minimum_nights                    0.003838             0.015345
# maximum_nights                   -0.027279             0.046048
# bathrooms                         0.071924             0.046500
# bed_type                         -0.066092             0.012469
# bedrooms                          0.123160             0.137997
# beds                              0.110656             0.124051
# cleaning_fee                      0.122726             0.236344
# guests_included                   0.040234             0.131984
# property_type                     0.087621             0.018368
# room_type                         0.083430            -0.224149
# square_feet                      -0.059414             0.019396
# city                             -0.003987            -0.044117
# latitude                         -0.056367             0.163159
# longitude                         0.017205             0.038429
# neighbourhood                    -0.000158            -0.036778
# neighbourhood_cleansed            0.017028             0.061558
# zipcode                           0.036856            -0.145561
# host_acceptance_rate              0.038366             0.122994
# host_is_superhost                -0.068517            -0.066133
# host_listings_count               0.211696            -0.139227
# host_response_time                0.067113             0.094567
# host_total_listings_count         0.211696            -0.139227
# number_of_reviews                -0.118965            -0.041595
# review_scores_accuracy           -0.093380            -0.014464
# price                             0.123922             0.179875
# security_deposit                  0.066869             0.150802
# extra_people                      0.148934             0.142982
# host_duration                     0.072809             0.022617
#
#                            instant_bookable  minimum_nights  maximum_nights  \
# availability_30                    0.005555        0.003838       -0.027279
# cancellation_policy                0.013951        0.015345        0.046048
# instant_bookable                   1.000000       -0.084281        0.077601
# minimum_nights                    -0.084281        1.000000       -0.012897
# maximum_nights                     0.077601       -0.012897        1.000000
# bathrooms                          0.049336       -0.006474       -0.021894
# bed_type                           0.026941        0.016330        0.008314
# bedrooms                          -0.033874        0.000786       -0.013596
# beds                               0.040765       -0.029169       -0.030250
# cleaning_fee                      -0.053094        0.150709       -0.012941
# guests_included                   -0.028241       -0.009859       -0.025548
# property_type                      0.098053       -0.017597       -0.033711
# room_type                          0.011157       -0.017921       -0.046233
# square_feet                        0.397756        0.078768       -0.116859
# city                               0.085455       -0.036505       -0.012581
# latitude                          -0.077440        0.003886        0.052322
# longitude                          0.067886       -0.058721        0.037751
# neighbourhood                     -0.052036       -0.056697        0.026879
# neighbourhood_cleansed             0.007670       -0.034152        0.043414
# zipcode                           -0.037950        0.010712       -0.061359
# host_acceptance_rate              -0.368598       -0.018032       -0.048008
# host_is_superhost                  0.016107        0.038689       -0.030320
# host_listings_count               -0.010203        0.034127       -0.000728
# host_response_time                 0.372098       -0.056160        0.034288
# host_total_listings_count         -0.010203        0.034127       -0.000728
# number_of_reviews                  0.347166       -0.085379        0.056188
# review_scores_accuracy            -0.120049        0.016862       -0.036306
# price                             -0.115770        0.014151       -0.011632
# security_deposit                  -0.059665        0.107407        0.081927
# extra_people                      -0.040258       -0.019921       -0.037619
# host_duration                      0.106735       -0.006683        0.028315
#
#                            bathrooms  bed_type  bedrooms      beds  \
# availability_30             0.071924 -0.066092  0.123160  0.110656
# cancellation_policy         0.046500  0.012469  0.137997  0.124051
# instant_bookable            0.049336  0.026941 -0.033874  0.040765
# minimum_nights             -0.006474  0.016330  0.000786 -0.029169
# maximum_nights             -0.021894  0.008314 -0.013596 -0.030250
# bathrooms                   1.000000  0.062163  0.354953  0.317810
# bed_type                    0.062163  1.000000  0.056108  0.065764
# bedrooms                    0.354953  0.056108  1.000000  0.705876
# beds                        0.317810  0.065764  0.705876  1.000000
# cleaning_fee                0.171428  0.118330  0.499173  0.474111
# guests_included             0.114269  0.071379  0.500858  0.500691
# property_type               0.305836  0.028693  0.017525  0.035634
# room_type                   0.062999 -0.243640 -0.250690 -0.346358
# square_feet                 0.346259 -0.064582  0.315808  0.176853
# city                        0.078732 -0.019982 -0.006758  0.043595
# latitude                   -0.120015  0.000280 -0.024605 -0.033420
# longitude                   0.039423 -0.022390  0.025362 -0.005279
# neighbourhood              -0.017255 -0.027613  0.017576  0.012479
# neighbourhood_cleansed     -0.019512 -0.029368  0.055457  0.028872
# zipcode                     0.027776  0.011196  0.000034 -0.010120
# host_acceptance_rate       -0.004652 -0.032378  0.024777 -0.046352
# host_is_superhost           0.056353  0.012308  0.016584 -0.052078
# host_listings_count         0.085909  0.027800  0.100485  0.059385
# host_response_time          0.066029 -0.011947  0.016036  0.039404
# host_total_listings_count   0.085909  0.027800  0.100485  0.059385
# number_of_reviews          -0.022103  0.045401 -0.166229 -0.108352
# review_scores_accuracy      0.007873  0.032655  0.110703  0.009916
# price                       0.220778  0.106256  0.565961  0.480744
# security_deposit            0.072246  0.104992  0.340480  0.289351
# extra_people                0.056045  0.018783  0.153906  0.185153
# host_duration              -0.018948  0.035435 -0.032280 -0.017792
#
#                            cleaning_fee  ...  host_is_superhost  \
# availability_30                0.122726  ...          -0.068517
# cancellation_policy            0.236344  ...          -0.066133
# instant_bookable              -0.053094  ...           0.016107
# minimum_nights                 0.150709  ...           0.038689
# maximum_nights                -0.012941  ...          -0.030320
# bathrooms                      0.171428  ...           0.056353
# bed_type                       0.118330  ...           0.012308
# bedrooms                       0.499173  ...           0.016584
# beds                           0.474111  ...          -0.052078
# cleaning_fee                   1.000000  ...           0.013066
# guests_included                0.350885  ...           0.053717
# property_type                 -0.226646  ...           0.060555
# room_type                     -0.567481  ...           0.086616
# square_feet                    0.610865  ...           0.048435
# city                          -0.120163  ...           0.057267
# latitude                       0.243305  ...          -0.159185
# longitude                      0.133372  ...          -0.109080
# neighbourhood                  0.003642  ...          -0.007473
# neighbourhood_cleansed         0.041802  ...           0.033198
# zipcode                       -0.179321  ...           0.085391
# host_acceptance_rate           0.100852  ...          -0.006486
# host_is_superhost              0.013066  ...           1.000000
# host_listings_count            0.230490  ...          -0.094973
# host_response_time            -0.041912  ...           0.090337
# host_total_listings_count      0.230490  ...          -0.094973
# number_of_reviews             -0.231631  ...           0.083362
# review_scores_accuracy         0.056735  ...           0.408530
# price                          0.647901  ...           0.010950
# security_deposit               0.491459  ...           0.083728
# extra_people                   0.059451  ...           0.107222
# host_duration                  0.081657  ...          -0.083664
#
#                            host_listings_count  host_response_time  \
# availability_30                       0.211696            0.067113
# cancellation_policy                  -0.139227            0.094567
# instant_bookable                     -0.010203            0.372098
# minimum_nights                        0.034127           -0.056160
# maximum_nights                       -0.000728            0.034288
# bathrooms                             0.085909            0.066029
# bed_type                              0.027800           -0.011947
# bedrooms                              0.100485            0.016036
# beds                                  0.059385            0.039404
# cleaning_fee                          0.230490           -0.041912
# guests_included                      -0.039290            0.058887
# property_type                        -0.074089            0.119012
# room_type                            -0.139808            0.046040
# square_feet                           0.119653            0.022308
# city                                 -0.038181            0.116989
# latitude                              0.073091            0.034465
# longitude                             0.020645            0.119824
# neighbourhood                        -0.054868           -0.080632
# neighbourhood_cleansed               -0.069318           -0.081795
# zipcode                              -0.063493            0.007894
# host_acceptance_rate                  0.023955           -0.245658
# host_is_superhost                    -0.094973            0.090337
# host_listings_count                   1.000000           -0.070799
# host_response_time                   -0.070799            1.000000
# host_total_listings_count             1.000000           -0.070799
# number_of_reviews                    -0.126435            0.287004
# review_scores_accuracy               -0.147696            0.001444
# price                                 0.209196           -0.044744
# security_deposit                      0.130311           -0.174013
# extra_people                         -0.094254            0.062310
# host_duration                         0.131989            0.010229
#
#                            host_total_listings_count  number_of_reviews  \
# availability_30                             0.211696          -0.118965
# cancellation_policy                        -0.139227          -0.041595
# instant_bookable                           -0.010203           0.347166
# minimum_nights                              0.034127          -0.085379
# maximum_nights                             -0.000728           0.056188
# bathrooms                                   0.085909          -0.022103
# bed_type                                    0.027800           0.045401
# bedrooms                                    0.100485          -0.166229
# beds                                        0.059385          -0.108352
# cleaning_fee                                0.230490          -0.231631
# guests_included                            -0.039290          -0.108504
# property_type                              -0.074089           0.134031
# room_type                                  -0.139808           0.073306
# square_feet                                 0.119653          -0.115471
# city                                       -0.038181           0.080697
# latitude                                    0.073091           0.013223
# longitude                                   0.020645           0.134300
# neighbourhood                              -0.054868          -0.044330
# neighbourhood_cleansed                     -0.069318           0.006136
# zipcode                                    -0.063493          -0.010773
# host_acceptance_rate                        0.023955          -0.175396
# host_is_superhost                          -0.094973           0.083362
# host_listings_count                         1.000000          -0.126435
# host_response_time                         -0.070799           0.287004
# host_total_listings_count                   1.000000          -0.126435
# number_of_reviews                          -0.126435           1.000000
# review_scores_accuracy                     -0.147696          -0.147719
# price                                       0.209196          -0.238114
# security_deposit                            0.130311          -0.281938
# extra_people                               -0.094254          -0.061479
# host_duration                               0.131989           0.426006
#
#                            review_scores_accuracy     price  security_deposit  \
# availability_30                         -0.093380  0.123922          0.066869
# cancellation_policy                     -0.014464  0.179875          0.150802
# instant_bookable                        -0.120049 -0.115770         -0.059665
# minimum_nights                           0.016862  0.014151          0.107407
# maximum_nights                          -0.036306 -0.011632          0.081927
# bathrooms                                0.007873  0.220778          0.072246
# bed_type                                 0.032655  0.106256          0.104992
# bedrooms                                 0.110703  0.565961          0.340480
# beds                                     0.009916  0.480744          0.289351
# cleaning_fee                             0.056735  0.647901          0.491459
# guests_included                          0.095600  0.402633          0.227642
# property_type                            0.021514 -0.199217         -0.194955
# room_type                                0.050367 -0.574663         -0.377848
# square_feet                              0.040070  0.540108          0.203935
# city                                     0.059610 -0.111300         -0.131212
# latitude                                -0.139874  0.267462          0.046149
# longitude                               -0.094822  0.132517         -0.055817
# neighbourhood                            0.037624 -0.051938          0.109731
# neighbourhood_cleansed                   0.086406 -0.014655          0.181335
# zipcode                                  0.072230 -0.261255         -0.131061
# host_acceptance_rate                     0.015071  0.075728          0.076873
# host_is_superhost                        0.408530  0.010950          0.083728
# host_listings_count                     -0.147696  0.209196          0.130311
# host_response_time                       0.001444 -0.044744         -0.174013
# host_total_listings_count               -0.147696  0.209196          0.130311
# number_of_reviews                       -0.147719 -0.238114         -0.281938
# review_scores_accuracy                   1.000000  0.101540          0.144927
# price                                    0.101540  1.000000          0.365105
# security_deposit                         0.144927  0.365105          1.000000
# extra_people                             0.091109  0.126617          0.052619
# host_duration                           -0.221776 -0.037809         -0.051168
#
#                            extra_people  host_duration
# availability_30                0.148934       0.072809
# cancellation_policy            0.142982       0.022617
# instant_bookable              -0.040258       0.106735
# minimum_nights                -0.019921      -0.006683
# maximum_nights                -0.037619       0.028315
# bathrooms                      0.056045      -0.018948
# bed_type                       0.018783       0.035435
# bedrooms                       0.153906      -0.032280
# beds                           0.185153      -0.017792
# cleaning_fee                   0.059451       0.081657
# guests_included                0.417987      -0.026359
# property_type                  0.022837       0.051480
# room_type                     -0.000109      -0.010405
# square_feet                    0.155015       0.163760
# city                           0.008094       0.061085
# latitude                      -0.054148      -0.002994
# longitude                     -0.052582       0.013583
# neighbourhood                  0.015025      -0.097914
# neighbourhood_cleansed         0.039315      -0.004443
# zipcode                       -0.034337      -0.020871
# host_acceptance_rate           0.022833       0.010353
# host_is_superhost              0.107222      -0.083664
# host_listings_count           -0.094254       0.131989
# host_response_time             0.062310       0.010229
# host_total_listings_count     -0.094254       0.131989
# number_of_reviews             -0.061479       0.426006
# review_scores_accuracy         0.091109      -0.221776
# price                          0.126617      -0.037809
# security_deposit               0.052619      -0.051168
# extra_people                   1.000000      -0.009226
# host_duration                 -0.009226       1.000000
#
# [31 rows x 31 columns]

# %%
cmap = sns.diverging_palette(220, 20, as_cmap=True)

# %%
fig, ax = plt.subplots(figsize=(11, 10))
sns.heatmap(hist2ddf.corr(), cmap=cmap, linewidths=.5, fmt='.2f', square=True);

# %% [markdown]
# #### Multivariate Insights:
#
# * Instantly bookable listings, have about 700$ as their max price, with 10 max rooms really while non instantly bookable rooms have a wider range of bed numbers, and prices.
# * For private rooms, there is a slight positive correlation between price and the number of extra people.
# * For entire homes/apartments, the correlation is less clear, with a wider spread of data points.
# * For shared rooms, there is minimal variation in the number of extra people regardless of price, with most data points clustered at lower prices.

# %% [markdown]
# #### Core Boston Exploration

# %%
hz.groupby(by='city').count()
# Out:
#                         availability_30  cancellation_policy  \
# city
# ALLSTON                              33                   33
# Allston                             413                  413
# Boston                            62350                62350
# Boston                               15                   15
# Boston (Charlestown)                  1                    1
# Boston (Jamaica Plain)               63                   63
# Brighton                            773                  773
# Brighton                              2                    2
# Brookline                           119                  119
# Cambridge                            57                   57
# Charlestown                         595                  595
# Dorchester                         1684                 1684
# East Boston                         263                  263
# Hyde Park                             5                    5
# Jamaica Plain                       616                  616
# Jamaica Plain                       117                  117
# Jamaica Plain (Boston)               14                   14
# Jamaica Plain, Boston                50                   50
# Jamaica Plain, MA                     5                    5
# Mattapan                             39                   39
# Milton                               10                   10
# Mission Hill, Boston                 34                   34
# ROXBURY CROSSING                     29                   29
# Roslindale                          290                  290
# Roslindale, Boston                   82                   82
# Roxbury Crossing                    230                  230
# Somerville                           19                   19
# South Boston                        142                  142
# South End, Boston                    19                   19
# West Roxbury                        111                  111
# boston                                1                    1
# dorchester, boston                    3                    3
# east Boston                          89                   89
#
#                         instant_bookable  minimum_nights  maximum_nights  \
# city
# ALLSTON                               33              33              33
# Allston                              413             413             413
# Boston                             62350           62350           62350
# Boston                                15              15              15
# Boston (Charlestown)                   1               1               1
# Boston (Jamaica Plain)                63              63              63
# Brighton                             773             773             773
# Brighton                               2               2               2
# Brookline                            119             119             119
# Cambridge                             57              57              57
# Charlestown                          595             595             595
# Dorchester                          1684            1684            1684
# East Boston                          263             263             263
# Hyde Park                              5               5               5
# Jamaica Plain                        616             616             616
# Jamaica Plain                        117             117             117
# Jamaica Plain (Boston)                14              14              14
# Jamaica Plain, Boston                 50              50              50
# Jamaica Plain, MA                      5               5               5
# Mattapan                              39              39              39
# Milton                                10              10              10
# Mission Hill, Boston                  34              34              34
# ROXBURY CROSSING                      29              29              29
# Roslindale                           290             290             290
# Roslindale, Boston                    82              82              82
# Roxbury Crossing                     230             230             230
# Somerville                            19              19              19
# South Boston                         142             142             142
# South End, Boston                     19              19              19
# West Roxbury                         111             111             111
# boston                                 1               1               1
# dorchester, boston                     3               3               3
# east Boston                           89              89              89
#
#                         bathrooms  bed_type  bedrooms   beds  cleaning_fee  \
# city
# ALLSTON                        33        33        33     33            31
# Allston                       413       413       413    413           157
# Boston                      61696     62350     62163  62237         42005
# Boston                         15        15        15     15             0
# Boston (Charlestown)            1         1         1      1             1
# Boston (Jamaica Plain)         63        63        63     63            63
# Brighton                      773       773       773    773           380
# Brighton                        2         2         2      2             2
# Brookline                     119       119       119    119           113
# Cambridge                      57        57        57     57            53
# Charlestown                   595       595       595    595           288
# Dorchester                   1573      1684      1684   1684          1682
# East Boston                   263       263       263    263           110
# Hyde Park                       5         5         5      5             0
# Jamaica Plain                 616       616       616    616           572
# Jamaica Plain                 117       117       117    117           117
# Jamaica Plain (Boston)         14        14        14     14            14
# Jamaica Plain, Boston          50        50        50     50            50
# Jamaica Plain, MA               5         5         5      5             5
# Mattapan                       39        39        39     39            39
# Milton                         10        10        10     10             0
# Mission Hill, Boston           34        34        34     34            34
# ROXBURY CROSSING               29        29        29     29            27
# Roslindale                    290       290       290    290            65
# Roslindale, Boston             82        82        82     82            82
# Roxbury Crossing              230       230       230    230           173
# Somerville                     19        19        19     19             4
# South Boston                  142       142       142    142           142
# South End, Boston              19        19        19     19            19
# West Roxbury                  111       111       111    111            89
# boston                          1         1         1      1             0
# dorchester, boston              3         3         3      3             3
# east Boston                    89        89        89     89             0
#
#                         ...  host_is_superhost  host_listings_count  \
# city                    ...
# ALLSTON                 ...                 33                   33
# Allston                 ...                413                  413
# Boston                  ...              62350                62350
# Boston                  ...                 15                   15
# Boston (Charlestown)    ...                  1                    1
# Boston (Jamaica Plain)  ...                 63                   63
# Brighton                ...                773                  773
# Brighton                ...                  2                    2
# Brookline               ...                119                  119
# Cambridge               ...                 57                   57
# Charlestown             ...                595                  595
# Dorchester              ...               1684                 1684
# East Boston             ...                263                  263
# Hyde Park               ...                  5                    5
# Jamaica Plain           ...                616                  616
# Jamaica Plain           ...                117                  117
# Jamaica Plain (Boston)  ...                 14                   14
# Jamaica Plain, Boston   ...                 50                   50
# Jamaica Plain, MA       ...                  5                    5
# Mattapan                ...                 39                   39
# Milton                  ...                 10                   10
# Mission Hill, Boston    ...                 34                   34
# ROXBURY CROSSING        ...                 29                   29
# Roslindale              ...                290                  290
# Roslindale, Boston      ...                 82                   82
# Roxbury Crossing        ...                230                  230
# Somerville              ...                 19                   19
# South Boston            ...                142                  142
# South End, Boston       ...                 19                   19
# West Roxbury            ...                111                  111
# boston                  ...                  1                    1
# dorchester, boston      ...                  3                    3
# east Boston             ...                 89                   89
#
#                         host_response_time  host_total_listings_count  \
# city
# ALLSTON                                 31                         33
# Allston                                409                        413
# Boston                               61291                      62350
# Boston                                  15                         15
# Boston (Charlestown)                     0                          1
# Boston (Jamaica Plain)                  63                         63
# Brighton                               773                        773
# Brighton                                 2                          2
# Brookline                              115                        119
# Cambridge                               57                         57
# Charlestown                            576                        595
# Dorchester                            1684                       1684
# East Boston                            263                        263
# Hyde Park                                5                          5
# Jamaica Plain                          614                        616
# Jamaica Plain                          117                        117
# Jamaica Plain (Boston)                  14                         14
# Jamaica Plain, Boston                   50                         50
# Jamaica Plain, MA                        5                          5
# Mattapan                                39                         39
# Milton                                  10                         10
# Mission Hill, Boston                    34                         34
# ROXBURY CROSSING                        27                         29
# Roslindale                             290                        290
# Roslindale, Boston                      82                         82
# Roxbury Crossing                       215                        230
# Somerville                              19                         19
# South Boston                           142                        142
# South End, Boston                       19                         19
# West Roxbury                           108                        111
# boston                                   0                          1
# dorchester, boston                       3                          3
# east Boston                             89                         89
#
#                         number_of_reviews  review_scores_accuracy  price  \
# city
# ALLSTON                                33                      33     33
# Allston                               413                     413    413
# Boston                              62350                   62276  62350
# Boston                                 15                      15     15
# Boston (Charlestown)                    1                       1      1
# Boston (Jamaica Plain)                 63                      63     63
# Brighton                              773                     773    773
# Brighton                                2                       2      2
# Brookline                             119                     118    119
# Cambridge                              57                      57     57
# Charlestown                           595                     595    595
# Dorchester                           1684                    1684   1684
# East Boston                           263                     263    263
# Hyde Park                               5                       5      5
# Jamaica Plain                         616                     616    616
# Jamaica Plain                         117                     117    117
# Jamaica Plain (Boston)                 14                      14     14
# Jamaica Plain, Boston                  50                      50     50
# Jamaica Plain, MA                       5                       5      5
# Mattapan                               39                      39     39
# Milton                                 10                      10     10
# Mission Hill, Boston                   34                      34     34
# ROXBURY CROSSING                       29                      27     29
# Roslindale                            290                     290    290
# Roslindale, Boston                     82                      82     82
# Roxbury Crossing                      230                     229    230
# Somerville                             19                      19     19
# South Boston                          142                     142    142
# South End, Boston                      19                      19     19
# West Roxbury                          111                     111    111
# boston                                  1                       1      1
# dorchester, boston                      3                       3      3
# east Boston                            89                      89     89
#
#                         security_deposit  extra_people  host_duration
# city
# ALLSTON                               31            33             33
# Allston                              154           413            413
# Boston                             27691         62350          62350
# Boston                                15            15             15
# Boston (Charlestown)                   0             1              1
# Boston (Jamaica Plain)                 0            63             63
# Brighton                             263           773            773
# Brighton                               0             2              2
# Brookline                             91           119            119
# Cambridge                             46            57             57
# Charlestown                          169           595            595
# Dorchester                          1638          1684           1684
# East Boston                           65           263            263
# Hyde Park                              0             5              5
# Jamaica Plain                        335           616            616
# Jamaica Plain                          0           117            117
# Jamaica Plain (Boston)                14            14             14
# Jamaica Plain, Boston                 50            50             50
# Jamaica Plain, MA                      5             5              5
# Mattapan                              39            39             39
# Milton                                 0            10             10
# Mission Hill, Boston                   0            34             34
# ROXBURY CROSSING                      27            29             29
# Roslindale                            25           290            290
# Roslindale, Boston                    82            82             82
# Roxbury Crossing                      46           230            230
# Somerville                            14            19             19
# South Boston                         142           142            142
# South End, Boston                      0            19             19
# West Roxbury                           0           111            111
# boston                                 0             1              1
# dorchester, boston                     3             3              3
# east Boston                            0            89             89
#
# [33 rows x 30 columns]

# %%
boston_df = hz[hz['city'].str.contains('Boston', case=False, na=False)]

# %%
plt.figure(figsize=(10,8.5))
sns.countplot(data=boston_df, x='property_type', order=plot_order('property_type'))
plt.xticks(rotation=45);

# %% [markdown]
# #### We see how much of Boston's listings are made up of purely 'Apartments', in percentage

# %%
len(boston_df[boston_df['property_type']=='Apartment']) / boston_df['property_type'].shape[0] * 100
# Out:
# 67.48883186008935

# %% [markdown]
# # SECTION V: DATA PREPROCESSING

# %%
def clean_data(df):
    '''
    INPUT
    df - pandas dataframe 
    
    OUTPUT
    X - A matrix holding all of the variables you want to consider when predicting the response
    y - the corresponding response vector
    
    This function cleans df using the following steps to produce X and y:
    1. Drop all the rows with no price
    2. Create X as all the columns that are not the price column
    3. Create y as the price column
    4. For each numeric variable in X, fill the column with the mean value of the column.
    5. Create dummy columns for all the categorical variables in X, drop the original columns
    '''
    
    # Drop rows with missing price values
    df = df.dropna(subset=['price'], axis=0)
    y = df['price']
    
    # Fill numeric columns with the mean
    num_vars = df.select_dtypes(include=['float', 'int']).columns
    for col in num_vars:
        df[col].fillna((df[col].mean()), inplace=True)
        
    # Dummy the categorical variables
    cat_vars = df.select_dtypes(include=['object']).copy().columns
    for var in  cat_vars:
        # for each cat add dummy var, drop original column
        df = pd.concat([df.drop(var, axis=1), pd.get_dummies(df[var], prefix=var, prefix_sep='_', drop_first=True)], axis=1)
    
    X = df
    return X, y
    
#Use the function to create X and y
X, y = clean_data(hz)

# %%
X.head()
# Out:
#    availability_30  minimum_nights  maximum_nights  bathrooms  bedrooms  beds  \
# 0                7               1            1125        1.0       1.0   1.0
# 1                7               1            1125        1.0       1.0   1.0
# 2                7               1            1125        1.0       1.0   1.0
# 3                7               1            1125        1.0       1.0   1.0
# 4                7               1            1125        1.0       1.0   1.0
#
#    cleaning_fee  guests_included  square_feet   latitude  ...  \
# 0     53.917638                1   586.221537  42.377796  ...
# 1     53.917638                1   586.221537  42.377796  ...
# 2     53.917638                1   586.221537  42.377796  ...
# 3     53.917638                1   586.221537  42.377796  ...
# 4     53.917638                1   586.221537  42.377796  ...
#
#    host_acceptance_rate_95.0  host_acceptance_rate_96.0  \
# 0                      False                      False
# 1                      False                      False
# 2                      False                      False
# 3                      False                      False
# 4                      False                      False
#
#    host_acceptance_rate_97.0  host_acceptance_rate_98.0  \
# 0                       True                      False
# 1                       True                      False
# 2                       True                      False
# 3                       True                      False
# 4                       True                      False
#
#    host_acceptance_rate_99.0  host_acceptance_rate_100.0  host_is_superhost_t  \
# 0                      False                       False                False
# 1                      False                       False                False
# 2                      False                       False                False
# 3                      False                       False                False
# 4                      False                       False                False
#
#    host_response_time_within a day  host_response_time_within a few hours  \
# 0                            False                                  False
# 1                            False                                  False
# 2                            False                                  False
# 3                            False                                  False
# 4                            False                                  False
#
#    host_response_time_within an hour
# 0                               True
# 1                               True
# 2                               True
# 3                               True
# 4                               True
#
# [5 rows x 235 columns]

# %%
X.columns          #access dummied variables
# Out:
# Index(['availability_30', 'minimum_nights', 'maximum_nights', 'bathrooms',
#        'bedrooms', 'beds', 'cleaning_fee', 'guests_included', 'square_feet',
#        'latitude',
#        ...
#        'host_acceptance_rate_95.0', 'host_acceptance_rate_96.0',
#        'host_acceptance_rate_97.0', 'host_acceptance_rate_98.0',
#        'host_acceptance_rate_99.0', 'host_acceptance_rate_100.0',
#        'host_is_superhost_t', 'host_response_time_within a day',
#        'host_response_time_within a few hours',
#        'host_response_time_within an hour'],
#       dtype='object', length=235)

# %%
y        #accessing our target variable
# Out:
# 0        95.0
# 1        95.0
# 2        95.0
# 3        95.0
# 4        95.0
#          ...
# 68270    75.0
# 68271    75.0
# 68272    75.0
# 68273    75.0
# 68274    75.0
# Name: price, Length: 68275, dtype: float64

# %%
#splitting into training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .3, random_state=42)

# %%
scaler = StandardScaler()        #scaling our features
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape               #shape accessments
# Out:
# (47792, 235)

# %%
X_test.shape
# Out:
# (20483, 235)

# %%
y_train.shape
# Out:
# (47792,)

# %% [markdown]
# # SECTION VI: MODEL BUILDING AND EVALUATION

# %% [markdown]
# ### 1. Linear Regression

# %%
linearmodel = LinearRegression()    #instantiating the linearmodel

# %%
linearmodel.fit(X_train, y_train)      #training model
# Out:
# LinearRegression()

# %%
y_test_preds = linearmodel.predict(X_test)

# %%
len(y_test_preds)
# Out:
# 20483

# %%
r2score = r2_score(y_test, y_test_preds)
print(f"LinearRegression R² Score: {r2score}")
rmse = mean_squared_error(y_test, y_test_preds)
print(f"LinearRegression Root Mean Squared Error Score: {rmse}")
mae = mean_absolute_error(y_test, y_test_preds)
print(f"LinearRegression MeanAbsoluteError Score: {mae}")
# Out:
# LinearRegression R² Score: 0.9999958420902032
# LinearRegression Root Mean Squared Error Score: 0.03731367545777522
# LinearRegression MeanAbsoluteError Score: 0.001956833217945627

# %% [markdown]
# #### Our overly high R2 score here can be a sign of overfitting.
# To further validate, we go ahead to build 2 other comparative models as well as predict using our training data in any one of them

# %% [markdown]
# ### 2. Random Forest Regressor

# %%
rfr = RandomForestRegressor(random_state=42)       #instantiating random forest

# %%
rfr.fit(X_train, y_train)         #training model
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = rfr.predict(X_test)        #predicting using model

# %%
r2score = r2_score(y_test, y_pred)         #scoring our model
print(f"RF R² Score: {r2score}")
rmse = mean_squared_error(y_test, y_pred)
print(f"RF Root Mean Squared Error Score: {rmse}")
mae = mean_absolute_error(y_test, y_pred)
print(f"RF MeanAbsoluteError Score: {mae}")
# Out:
# RF R² Score: 0.9999997264931931
# RF Root Mean Squared Error Score: 0.002454489088512445
# RF MeanAbsoluteError Score: 0.0017599960943221046

# %% [markdown]
# #### Predicitng using our training data

# %%
y_train_pred = rfr.predict(X_train)            #predicting using training data

# %%
r2_train = r2_score(y_train, y_train_pred)               #scoring the trained data
rmse_train = mean_squared_error(y_train, y_train_pred, squared=False)
mae_train = mean_absolute_error(y_train, y_train_pred)

print(f"Training R²: {r2_train}")
print(f"Training RMSE: {rmse_train}")
print(f"Training MAE: {mae_train}")
# Out:
# Training R²: 0.999997307936234
# Training RMSE: 0.15696072539664324
# Training MAE: 0.0021951372614663453

# %% [markdown]
# ### 3. XGBoost Regressor

# %%
xgb_model = XGBRegressor(random_state=21, n_estimators=500)      #instantiating xgboost

# %%
xgb_model.fit(X_train, y_train)               #training model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=21, ...)

# %%
y_xgb_test = xgb_model.predict(X_test)

# %%
r2score = r2_score(y_test, y_xgb_test)
print(f"XGB R² Score: {r2score}")
rmse = mean_squared_error(y_test, y_xgb_test)
print(f"XGB Root Mean Squared Error Score: {rmse}")
mae = mean_absolute_error(y_test, y_xgb_test)
print(f"XGB MeanAbsoluteError Score: {mae}")
# Out:
# XGB R² Score: 0.9999973357366804
# XGB Root Mean Squared Error Score: 0.023909478969220726
# XGB MeanAbsoluteError Score: 0.010826843683359849

# %% [markdown]
# # SECTION VII: PROJECT OBJECTIVE

# %% [markdown]
# ### Reserach Questions:
#
# 1. What is the general outlook of the reviews comments ?
# 2. As a prospective Airbnb host, what sort of apartment do I need to have to increase my chances of making profit off rentals
# 3. What factors

# %% [markdown]
# ### 1. What is the general outlook of the reviews comments ?

# %%
plt.figure(figsize=(10,8.5))
sns.countplot(data=reviews, x='review_grade', order=reviews_order)
plt.title('Distribution of Listings\' Reviews')
plt.xlabel('Polarity of Review')
plt.ylabel('Polarity Count');

# %% [markdown]
# ##### Here, comments are a bit Positive rather than any other grade really.
#
# This shows a distinctly high satisfaction amongst reviewers outlooks of listings

# %% [markdown]
# ### 2. As a prospective Airbnb host, what sort of apartment do I need to have to increase my chances of making profit off rentals

# %% [markdown]
# From wrangling, a couple insights have been gotten from these;
#
# * People prefer rentals giving out the entire apartments
# * Adding to this, 1 bedroom apartments would be preferred, maybe because it correlates with the price, or probably because its has the  1 room to 1 guest ratio
# * In everyhome, real beds are most, more than any other to be fair.

# %% [markdown]
# ### 3. What factors affect price the most ?

# %% [markdown]
# Visualising our correlelogram, assuming our encoding is all accurate,
#
# * Beds
# * Cleaning fee
# * Bedroom
#
# affect our price variable the most

# %%
cmap = sns.diverging_palette(220, 20, as_cmap=True)

# %%
fig, ax = plt.subplots(figsize=(15, 10))
sns.heatmap(hist2ddf.corr(), cmap=cmap, linewidths=.5, fmt='.2f', square=True);
